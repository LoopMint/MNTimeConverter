# %% [markdown]
# <a href="https://colab.research.google.com/github/LoopMint/MNTimeConverter/blob/main/Timezone_Conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML, display

html_code = """
<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8">
    <title>Singapore and Minnesota Clocks</title>
    <style>
      body {
        font-family: Arial, sans-serif;
        font-size: 28px;
        text-align: center;
        padding-top: 60px;
        background-color: #f4f4f4;
      }
      #sg-clock, #mn-clock {
        margin: 20px 0;
        color: #333;
      }
    </style>
    <script>
      function updateClocks() {
        const sgOptions = {
          timeZone: 'Asia/Singapore',
          weekday: 'long',
          year: 'numeric',
          month: 'short',
          day: '2-digit',
          hour: 'numeric',
          minute: '2-digit',
          second: '2-digit',
          hour12: true
        };

        const mnOptions = {
          timeZone: 'America/Chicago',
          weekday: 'long',
          year: 'numeric',
          month: 'short',
          day: '2-digit',
          hour: 'numeric',
          minute: '2-digit',
          second: '2-digit',
          hour12: true
        };

        const sgTime = new Date().toLocaleString('en-US', sgOptions);
        const mnTime = new Date().toLocaleString('en-US', mnOptions);

        document.getElementById("sg-clock").innerHTML = "Singapore: " + sgTime;
        document.getElementById("mn-clock").innerHTML = "Minnesota: " + mnTime;
      }

      setInterval(updateClocks, 1000);
    </script>
  </head>
  <body onload="updateClocks()">
    <div id="sg-clock">Loading Singapore time...</div>
    <div id="mn-clock">Loading Minnesota time...</div>
  </body>
</html>
"""

display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <title>Singapore and Minnesota Clocks</title>
#     <style>
#       body {
#         font-family: Arial, sans-serif;
#         font-size: 28px;
#         text-align: center;
#         padding-top: 60px;
#         background-color: #f4f4f4;
#       }
#       #sg-clock, #mn-clock {
#         margin: 20px 0;
#         color: #333;
#       }
#     </style>
#     <script>
#       function updateClocks() {
#         const sgOptions = {
#           timeZone: 'Asia/Singapore',
#           weekday: 'long',
#           year: 'numeric',
#           month: 'short',
#           day: '2-digit',
#           hour: 'numeric',
#           minute: '2-digit',
#           second: '2-digit',
#           hour12: true
#         };
#
#         const mnOptions = {
#           timeZone: 'America/Chicago',
#           weekday: 'long',
#           year: 'numeric',
#           month: 'short',
#           day: '2-digit',
# ...

# %%
from IPython.display import IFrame

IFrame('https://drive.google.com/file/d/1F_8UqemQ7WcACeuXOnNcmXetxXPPpG-9/view?usp=sharing', width=700, height=400)
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="https://drive.google.com/file/d/1F_8UqemQ7WcACeuXOnNcmXetxXPPpG-9/view?usp=sharing"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import HTML, display

# Combined HTML: clocks + schedule table
html_combined = """
<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8">
    <title>Singapore and Minnesota Clocks + Schedule</title>
    <style>
      body {
        font-family: Arial, sans-serif;
        background-color: #fdfdfd;
        padding-bottom: 40px;
      }
      h2 {
        color: red;
        text-align: center;
        margin-top: 50px;
      }
      /* Clock styles */
      #sg-clock, #mn-clock {
        text-align: center;
        font-size: 28px;
        margin-top: 20px;
        color: #333;
      }
      /* Table styles */
      table {
        border-collapse: collapse;
        margin: 30px auto;
        width: 95%;
      }
      th, td {
        border: 1px solid #ccc;
        padding: 12px;
        vertical-align: top;
        text-align: left;
      }
      th {
        background-color: #f2f2f2;
      }
      tr:nth-child(even) {
        background-color: #fafafa;
      }
      .date-header {
        font-weight: bold;
        color: #444;
        font-size: 16px;
      }
      .day-name {
        font-weight: bold;
        color: #2c3e50;
        font-size: 14px;
        margin-top: 4px;
        display: block;
      }
      .pm-leave {
        background-color: #fff8b3;
      }
    </style>
    <script>
      function updateClocks() {
        const sgOptions = {
          timeZone: 'Asia/Singapore',
          weekday: 'long',
          year: 'numeric',
          month: 'short',
          day: '2-digit',
          hour: 'numeric',
          minute: '2-digit',
          second: '2-digit',
          hour12: true
        };

        const mnOptions = {
          timeZone: 'America/Chicago',
          weekday: 'long',
          year: 'numeric',
          month: 'short',
          day: '2-digit',
          hour: 'numeric',
          minute: '2-digit',
          second: '2-digit',
          hour12: true
        };

        const sgTime = new Date().toLocaleString('en-US', sgOptions);
        const mnTime = new Date().toLocaleString('en-US', mnOptions);

        document.getElementById("sg-clock").innerHTML = "🇸🇬 Singapore: " + sgTime;
        document.getElementById("mn-clock").innerHTML = "🇺🇸 Minnesota: " + mnTime;
      }

      setInterval(updateClocks, 1000);
    </script>
  </head>
  <body onload="updateClocks()">
    <div id="sg-clock">Loading Singapore time...</div>
    <div id="mn-clock">Loading Minnesota time...</div>

    <h2>⚠️ Alert: Upcoming Schedule (SGT ➝ MN Time)</h2>
    <table>
      <tr>
        <th>Date</th>
        <th>Event (SGT)</th>
        <th>Equivalent (MN Time / CDT)</th>
      </tr>
      <tr>
        <td><span class="date-header">7 July</span><br><span class="day-name">Monday</span></td>
        <td class="pm-leave">PM Leave: 12:30pm – 5:30pm<br>Capstone: 9:00am – 6:00pm</td>
        <td class="pm-leave">Leave: 11:30pm (6 Jul) – 4:30am (7 Jul)<br>Capstone: 8:00pm (6 Jul) – 5:00am (7 Jul)</td>
      </tr>
      <tr>
        <td><span class="date-header">8 July</span><br><span class="day-name">Tuesday</span></td>
        <td>Meetings at 11:00am and 3:00pm</td>
        <td>10:00pm (7 Jul) and 2:00am (8 Jul)</td>
      </tr>
      <tr>
        <td><span class="date-header">9 July</span><br><span class="day-name">Wednesday</span></td>
        <td>Meeting at 3:00pm</td>
        <td>2:00am (9 Jul)</td>
      </tr>
      <tr>
        <td><span class="date-header">10 July</span><br><span class="day-name">Thursday</span></td>
        <td>On Leave</td>
        <td>On Leave</td>
      </tr>
      <tr>
        <td><span class="date-header">11 July</span><br><span class="day-name">Friday</span></td>
        <td class="pm-leave">PM Leave: 12:30pm – 5:30pm<br>Capstone Presentation: 11:00am – 11:40am</td>
        <td class="pm-leave">Leave: 11:30pm (10 Jul) – 4:30am (11 Jul)<br>Presentation: 10:00pm – 10:40pm (10 Jul)</td>
      </tr>
      <tr>
        <td><span class="date-header">14 July</span><br><span class="day-name">Monday</span></td>
        <td>Capstone: 9:00am – 6:00pm<br>Meeting at 1:30pm</td>
        <td>Capstone: 8:00pm (13 Jul) – 5:00am (14 Jul)<br>Meeting: 12:30am (14 Jul)</td>
      </tr>
      <tr>
        <td><span class="date-header">15 July</span><br><span class="day-name">Tuesday</span></td>
        <td>Meetings at 11:00am and 3:00pm</td>
        <td>10:00pm (14 Jul) and 2:00am (15 Jul)</td>
      </tr>
      <tr>
        <td><span class="date-header">16 July</span><br><span class="day-name">Wednesday</span></td>
        <td>Meeting at 3:00pm</td>
        <td>2:00am (16 Jul)</td>
      </tr>
      <tr>
        <td><span class="date-header">21 July</span><br><span class="day-name">Monday</span></td>
        <td>Meeting at 1:30pm</td>
        <td>12:30am (21 Jul)</td>
      </tr>
      <tr>
        <td><span class="date-header">23 July</span><br><span class="day-name">Thursday</span></td>
        <td>On Leave</td>
        <td>On Leave</td>
      </tr>
      <tr>
        <td><span class="date-header">25 July</span><br><span class="day-name">Thursday</span></td>
        <td>On Leave</td>
        <td>On Leave</td>
      </tr>
    </table>
  </body>
</html>
"""

display(HTML(html_combined))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <title>Singapore and Minnesota Clocks + Schedule</title>
#     <style>
#       body {
#         font-family: Arial, sans-serif;
#         background-color: #fdfdfd;
#         padding-bottom: 40px;
#       }
#       h2 {
#         color: red;
#         text-align: center;
#         margin-top: 50px;
#       }
#       /* Clock styles */
#       #sg-clock, #mn-clock {
#         text-align: center;
#         font-size: 28px;
#         margin-top: 20px;
#         color: #333;
#       }
#       /* Table styles */
#       table {
#         border-collapse: collapse;
#         margin: 30px auto;
#         width: 95%;
#       }
#       th, td {
#         border: 1px solid #ccc;
#         padding: 12px;
#         vertical-align: top;
#         text-align: left;
#       }
#       th {
#         background-color: #f2f2f2;
#       }
#       tr:nth-child(even) {
#         background-color: #fafafa;
#       }
# ...
